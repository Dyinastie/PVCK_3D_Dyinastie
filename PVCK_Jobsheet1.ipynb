# %% [markdown]
# <a href="https://colab.research.google.com/github/Dyinastie/PVCK_3D_Dyinastie/blob/main/PVCK_Jobsheet1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **JOBSHEET 1**
#
# *  Nama : Dyinastie Marchelina Puspitawening
# *  Kelas : TI-3G
# *  No. Absen : 08

# %% [markdown]
# **Langkah (Step) 1 : Penggunaan Library**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# **Langkah (Step) 2 : Membaca image dari URLS**

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://cdn-cas.orami.co.id/parenting/images/kucing_gemas-1.width-800.jpg"]
# Baca dan tampilkan image
# Loop pada tiap url image, beberapa dapat disimpan pasa list
for url in urls:
  image = io.imread(url)                            # read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    # convert color to RGB
  final_frame = cv.hconcat((image, image_2))        # concatenate image
  cv2_imshow(final_frame)                           # show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x400>

# %% [markdown]
# **Langkah (Step) 3 : Melihat ukuran file image**

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  400  x  400
# <PIL.Image.Image image mode=RGB size=400x400>

# %% [markdown]
# **Langkah (Step) 4 : Mengakses pixel**

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal di tengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %% [markdown]
# **Pertanyaan**
#
# 1.   Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
# > Karena Google Colab merupakan tools yang berbasis cloud, gratis, dan mendukung banyak library yang dibutuhkan. Google Colab memungkinkan untuk menulis, mengeksekusi, dan menyimpan kode Phyton di browser tanpa memerlukan konfigurasi dan proses instalasi dengan mendownload pada komputer sehingga lebih mudah untuk diakases dan dibagikan.
#
# 2.  Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
#
# *   numpy : digunakan untuk manipulasi array, aljabar linear, transformasi Fourier, dan kemampuan bilangan acak.
# *   pandas : digunakan untuk manipulasi data dan analisis data.
# *   cv2 (OpenCV) : digunakan untuk tugas-tugas visi komputer.
# *   google.colab.patches : digunakan untu menampilkan gambar.
# *   skimage (Scikit-image) : digunakan untuk mendukung pengolahan gambar dengan phyton.
# *   PIL (Pillow) : digunakan  untuk membuka, memanipulasi, dan menyimpan gambar.
# *   matplotlib : digunakan untuk menghasilkan gambar dan menyediakan perangkat anatarmuka pengguna grafis.
#
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# > Dari library tersebut, cv2, skimage, dan google.colap.patches yang paling sering digunakan untuk praktikum ini. Sedangkan library lainnya tidak harus digunakan karena hanya perlu memakai yang diperlukan saja.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut:`image = cv.resize(image, (0,0), fx=0.5, fy=0.5)`. Apa kegunaan kode program tersebut?
#
# > Fungsi cv.resize digunakan untuk mengubah ukuran gambar. Parameter (0,0) menunjukkan bahwa ukuran output gambar akan ditentukan oleh parameter skala fx dan fy. Parameter fx=0.5 dan fy=0.5 menunjukkan faktor skala untuk lebar (fx) dan tinggi (fy) gambar. Dalam hal ini, gambar akan diubah ukurannya menjadi setengah dari ukuran aslinya baik dalam lebar maupun tinggi. Dengan kata lain, kode ini akan mengecilkan ukuran gambar menjadi 50% dari ukuran asli.
#
# Dan apa pengaruhnya jika tidak dilakukan?
#
# > Jika kode ini tidak dijalankan, gambar yang dihasilkan dan diproses akan tetap pada ukuran aslinya. Ini mungkin mengakibatkan gambar yang ditampilkan lebih besar atau lebih sulit dilihat, terutama jika gambar aslinya sangat besar.
#
# 4. Perhatikan potongan kode progam berikut:
#
# ```
# # Membuat garis horizontal di tengah image
# for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]
# ```
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
# > Kode tersebut digunakan untuk mengatur warna piksel menjadi putih, dimana  255 untuk merah (Red), 255 untuk hijau (Green), 255 untuk biru (Blue), sehingga ketiga komponen ini diatur pada nilai maksimum mereka, yaitu 255, yang menghasilkan warna putih dalam sistem warna RGB.
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# > Pixel adalah unit dasar dari gambar digital, dan resolusi gambar menentukan jumlah piksel dalam gambar tersebut. Gambar dengan resolusi tinggi memiliki lebih banyak piksel, menghasilkan detail yang lebih baik dan kualitas visual yang lebih tinggi, sementara gambar dengan resolusi rendah memiliki lebih sedikit piksel, dengan kualitas dan detail yang lebih rendah.

# %% [markdown]
# **TUGAS**

# %% [markdown]
# 1.	Lakukan langkah-langkah praktikum seperti diatas
#
# 2.	Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis vertikal di tengah image
for y in range (tinggi):
  image_3[y, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis diagonal dari kiri atas ke kanan bawah
for y in range(min(tinggi, lebar)):
    image_3[y, y] = [255, 255, 255]

# Membuat garis diagonal dari kanan atas ke kiri bawah
for y in range(min(tinggi, lebar)):
    image_3[y, lebar - 1 - y] = [255, 255, 255]

# Menggabungkan gambar secara horizontal dan menampilkannya
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %% [markdown]
# 3.	Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Menentukan panjang garis horizontal
panjang_garis = 100       # Panjang garis yang diinginkan

# Menentukan titik awal dan akhir dari garis horizontal
awal_x = int((lebar - panjang_garis) / 3)
akhir_x = awal_x + panjang_garis

# Membuat garis horizontal di tengah image dengan panjang tertentu
for x in range(awal_x, akhir_x):
  image_3[int(tinggi / 2), x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %% [markdown]
# 4.	Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Menentukan posisi dan ukuran kotak
kotak_lebar = 80    # Lebar kotak
kotak_tinggi = 80   # Tinggi kotak

# Menentukan letak koordinat kotak
x_awal = 100  # Koordinat x dari sudut kiri atas kotak
y_awal = 100  # Koordinat y dari sudut kiri atas kotak

# Membuat kotak dengan kumpulan piksel warna putih
for y in range(y_awal, y_awal + kotak_tinggi):
    for x in range(x_awal, x_awal + kotak_lebar):
        image_3[y, x] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400>

# %% [markdown]
# **TUGAS**

# %% [markdown]
# 1.  Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# Akses file lokal

ktp_path = '/content/Contoh KTP.jpg'
ktp = io.imread(ktp_path)                       # read image
ktp = cv.resize(ktp, (0,0), fx=0.5, fy=0.5)     # resize image to half size
ktp_1 = cv.cvtColor(ktp, cv.COLOR_BGR2RGB)      # convert color to RGB

# Tampilan menggunakan OpenCV

print("Tampilan menggunakan OpenCV")
cv2_imshow(ktp_1)

# Tampilan menggunakan Matplotlib

print("Tampilan menggunakan Matplotlib")
ktp_rgb = cv.cvtColor(ktp_1, cv.COLOR_BGR2RGB)
plt.imshow(ktp_rgb)
plt.axis('off')  # Hide axes
plt.show()
# Out:
# Tampilan menggunakan OpenCV
# <PIL.Image.Image image mode=RGB size=400x248>
# Tampilan menggunakan Matplotlib

# %% [markdown]
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada Matplotlib dan tanpa konversi pada OpenCV
#
#
# > Sebelum ditampilkan, warna KTP telah dikonversi ke format RGB yang ditandai dengan kode berikut:
# ```
# ktp_1 = cv.cvtColor(ktp, cv.COLOR_BGR2RGB)
# ```
# Sehingga OpenCV langsung dapat menampilkan gambar dalam format RGB dan tanpa perlu konversi lagi. Sedangkan jika menggunakan Matplotlib maka akan menampilkan gambar dengan format BGR karena telah mengalami konversi sebelumnya, oleh karena itu perlu konversi lagi ke format RGB agar warna yang ditampilkan benar.

# %% [markdown]
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut.Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh
# menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %%
ktp_2 = cv.cvtColor(ktp, cv.COLOR_BGR2RGB)

# Menutupi area NIK

NIK_lebar = 160   # Lebar kotak
NIK_tinggi = 15   # Tinggi kotak
x1_awal = 95      # Koordinat x dari sudut kiri atas kotak
y1_awal = 40      # Koordinat y dari sudut kiri atas kotak

for y in range(y1_awal, y1_awal + NIK_tinggi):
    for x in range(x1_awal, x1_awal + NIK_lebar):
        ktp_2[y, x] = [0, 255, 255]

# Menutupi area Nama

Nama_lebar = 40     # Lebar kotak
Nama_tinggi = 10    # Tinggi kotak
x2_awal = 108       # Koordinat x dari sudut kiri atas kotak
y2_awal = 63        # Koordinat y dari sudut kiri atas kotak

for y in range(y2_awal, y2_awal + Nama_tinggi):
    for x in range(x2_awal, x2_awal + Nama_lebar):
        ktp_2[y, x] = [255, 0, 255]

cv2_imshow(ktp_2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x248>
